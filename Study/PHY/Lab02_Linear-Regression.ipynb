# %%
import tensorflow as tf

# %%
# x_train = [1, 2, 3]
# y_train = [2, 4, 6]
X = tf.placeholder(tf.float32, shape = [None]) # shape에 None은 값의 개수에 제한이 없다는 뜻
Y = tf.placeholder(tf.float32, shape = [None])

W = tf.Variable(tf.random_normal([1]), name = 'weight')
b = tf.Variable(tf.random_normal([1]), name = 'bias')

hypothesis = X * W + b

# %%
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# reduce_mean(t) => 평균 내주는 함수

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train = optimizer.minimize(cost)

# graph 구현 완료
# train(node) <- cost <- hy <- w, b 순으로 연결되어있음

# %%
sess = tf.Session()

sess.run(tf.global_variables_initializer())

for step in range(2001):
    # X, Y값을 placeholder로 주면 feed_dict를 통해 학습 데이터를 직접 지정할 수 있다.
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], 
                                         feed_dict = {X : [1, 2, 3, 4, 5], Y : [2.1, 3.1, 4.1, 5.1, 6.1]})

    if step % 20 == 0 :
        print(step, cost_val, W_val, b_val)
# Out:
# 0 5.92697 [ 0.29317248] [ 1.64247751]
# 20 0.0753562 [ 0.82018775] [ 1.74010313]
# 40 0.0657051 [ 0.83413512] [ 1.69878364]
# 60 0.0573808 [ 0.8450076] [ 1.65957153]
# 80 0.0501111 [ 0.85515815] [ 1.62292492]
# 100 0.0437624 [ 0.86464399] [ 1.58867812]
# 120 0.038218 [ 0.87350857] [ 1.556674]
# 140 0.033376 [ 0.88179266] [ 1.52676606]
# 160 0.0291475 [ 0.88953412] [ 1.49881697]
# 180 0.0254548 [ 0.89676857] [ 1.47269809]
# 200 0.0222299 [ 0.90352929] [ 1.44828963]
# 220 0.0194135 [ 0.90984726] [ 1.42547989]
# 240 0.0169539 [ 0.91575146] [ 1.40416384]
# 260 0.014806 [ 0.921269] [ 1.38424397]
# 280 0.0129302 [ 0.9264251] [ 1.36562872]
# 300 0.011292 [ 0.93124354] [ 1.34823251]
# 320 0.00986143 [ 0.93574643] [ 1.33197558]
# 340 0.00861204 [ 0.93995452] [ 1.31678319]
# 360 0.00752096 [ 0.943887] [ 1.30258572]
# 380 0.00656809 [ 0.94756186] [ 1.28931808]
# 400 0.00573597 [ 0.9509961] [ 1.27691948]
# 420 0.00500927 [ 0.95420539] [ 1.26533282]
# 440 0.00437462 [ 0.95720458] [ 1.25450504]
# 460 0.0038204 [ 0.96000725] [ 1.24438643]
# 480 0.00333638 [ 0.9626264] [ 1.2349304]
# 500 0.00291368 [ 0.96507406] [ 1.22609365]
# 520 0.00254454 [ 0.96736133] [ 1.21783578]
# 540 0.00222216 [ 0.96949893] [ 1.21011853]
# 560 0.00194063 [ 0.97149646] [ 1.20290673]
# 580 0.00169477 [ 0.97336316] [ 1.19616723]
# 600 0.00148004 [ 0.97510779] [ 1.18986881]
# 620 0.00129253 [ 0.97673804] [ 1.18398309]
# 640 0.00112877 [ 0.97826147] [ 1.17848289]
# 660 0.000985772 [ 0.97968507] [ 1.17334318]
# 680 0.000860879 [ 0.9810155] [ 1.16853988]
# 700 0.000751819 [ 0.98225886] [ 1.16405118]
# 720 0.000656574 [ 0.98342067] [ 1.15985668]
# 740 0.000573386 [ 0.98450649] [ 1.15593648]
# 760 0.000500742 [ 0.98552114] [ 1.15227306]
# 780 0.000437295 [ 0.98646945] [ 1.14884937]
# 800 0.000381891 [ 0.98735559] [ 1.14565027]
# 820 0.000333508 [ 0.98818368] [ 1.14266062]
# 840 0.000291253 [ 0.9889577] [ 1.13986635]
# 860 0.000254355 [ 0.98968077] [ 1.13725555]
# 880 0.000222131 [ 0.99035656] [ 1.13481557]
# 900 0.000193989 [ 0.99098814] [ 1.13253558]
# 920 0.000169413 [ 0.99157834] [ 1.13040495]
# 940 0.00014795 [ 0.99212986] [ 1.12841368]
# 960 0.000129204 [ 0.99264532] [ 1.12655282]
# 980 0.000112835 [ 0.99312693] [ 1.1248138]
# 1000 9.85419e-05 [ 0.99357712] [ 1.12318873]
# 1020 8.60559e-05 [ 0.99399769] [ 1.12167013]
# 1040 7.51576e-05 [ 0.99439067] [ 1.1202513]
# 1060 6.56337e-05 [ 0.99475801] [ 1.11892509]
# 1080 5.73198e-05 [ 0.99510139] [ 1.11768568]
# 1100 5.00556e-05 [ 0.99542218] [ 1.1165272]
# 1120 4.3714e-05 [ 0.99572206] [ 1.11544466]
# 1140 3.81755e-05 [ 0.99600226] [ 1.11443305]
# 1160 3.3339e-05 [ 0.99626404] [ 1.11348796]
# 1180 2.9115e-05 [ 0.99650878] [ 1.1126045]
# 1200 2.54262e-05 [ 0.99673742] [ 1.11177897]
# 1220 2.22045e-05 [ 0.9969511] [ 1.11100757]
# 1240 1.93914e-05 [ 0.99715078] [ 1.11028636]
# 1260 1.69339e-05 [ 0.9973374] [ 1.1096127]
# 1280 1.47876e-05 [ 0.9975118] [ 1.10898304]
# 1300 1.29146e-05 [ 0.9976747] [ 1.10839462]
# 1320 1.1278e-05 [ 0.99782711] [ 1.10784495]
# 1340 9.849e-06 [ 0.99796939] [ 1.10733104]
# 1360 8.60138e-06 [ 0.99810237] [ 1.10685086]
# 1380 7.51146e-06 [ 0.99822664] [ 1.10640228]
# 1400 6.55965e-06 [ 0.99834281] [ 1.1059829]
# 1420 5.7288e-06 [ 0.99845129] [ 1.10559106]
# 1440 5.00306e-06 [ 0.99855274] [ 1.10522485]
# 1460 4.36935e-06 [ 0.99864751] [ 1.10488272]
# 1480 3.81538e-06 [ 0.99873608] [ 1.10456288]
# 1500 3.33171e-06 [ 0.99881893] [ 1.10426402]
# 1520 2.90969e-06 [ 0.99889636] [ 1.10398459]
# 1540 2.54115e-06 [ 0.9989686] [ 1.10372365]
# 1560 2.219e-06 [ 0.99903613] [ 1.10347986]
# 1580 1.93838e-06 [ 0.9990992] [ 1.10325193]
# 1600 1.69249e-06 [ 0.9991582] [ 1.10303903]
# 1620 1.47823e-06 [ 0.99921328] [ 1.10284007]
# 1640 1.29093e-06 [ 0.99926484] [ 1.10265398]
# 1660 1.12731e-06 [ 0.999313] [ 1.10248005]
# 1680 9.84502e-07 [ 0.999358] [ 1.10231769]
# 1700 8.59545e-07 [ 0.99940002] [ 1.10216582]
# 1720 7.50834e-07 [ 0.9994393] [ 1.10202396]
# 1740 6.55811e-07 [ 0.99947602] [ 1.10189152]
# 1760 5.72689e-07 [ 0.99951035] [ 1.10176766]
# 1780 5.00215e-07 [ 0.99954236] [ 1.10165203]
# 1800 4.36876e-07 [ 0.99957228] [ 1.10154378]
# 1820 3.81472e-07 [ 0.99960035] [ 1.10144281]
# 1840 3.33177e-07 [ 0.99962652] [ 1.10134828]
# 1860 2.90915e-07 [ 0.99965096] [ 1.10126007]
# 1880 2.54002e-07 [ 0.99967384] [ 1.10117733]
# 1900 2.21832e-07 [ 0.99969524] [ 1.10110033]
# 1920 1.93769e-07 [ 0.99971515] [ 1.10102832]
# 1940 1.69263e-07 [ 0.99973375] [ 1.10096097]
# 1960 1.47791e-07 [ 0.99975121] [ 1.10089791]
# 1980 1.29119e-07 [ 0.99976748] [ 1.10083926]
# 2000 1.12727e-07 [ 0.99978274] [ 1.1007843]

# %%
# Testing model
print(sess.run(hypothesis, feed_dict = {X : [5]}))
print(sess.run(hypothesis, feed_dict = {X : [2.5]}))
print(sess.run(hypothesis, feed_dict = {X : [1.5, 3.5]}))
# Out:
# [ 6.09969807]
# [ 3.60024118]
# [ 2.60045838  4.60002422]
